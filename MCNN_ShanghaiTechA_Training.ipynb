# %% [markdown]
# ##**Note**: Change Runtime type to "GPU" before connecting to runtime or you will face issues

# %% [markdown]
# Credits for our MCNN baseline model: https://www.kaggle.com/code/wptouxx/shtech-mcnn

# %%
import warnings
warnings.filterwarnings("ignore")
# !pip install opendatasets --upgrade --quiet
import opendatasets as od
od.version()
# Out:
# '0.1.22'

# %%
# !git clone https://github.com/nksrivastavaa/DL_project_files
# Out:
# Cloning into 'DL_project_files'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 10 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (10/10), 15.78 MiB | 8.97 MiB/s, done.

# %%
# !unzip /content/DL_project_files/ShanghaiTech.zip
# Out:
# Archive:  /content/DL_project_files/ShanghaiTech.zip
#    creating: ShanghaiTech/part_A/
#    creating: ShanghaiTech/part_A/test_data/
#    creating: ShanghaiTech/part_A/test_data/ground-truth/
#  extracting: ShanghaiTech/part_A/test_data/ground-truth/GT_IMG_1.mat
#  extracting: ShanghaiTech/part_A/test_data/ground-truth/GT_IMG_10.mat
#   inflating: ShanghaiTech/part_A/test_data/ground-truth/GT_IMG_2.mat
#  extracting: ShanghaiTech/part_A/test_data/ground-truth/GT_IMG_3.mat
#  extracting: ShanghaiTech/part_A/test_data/ground-truth/GT_IMG_4.mat
#   inflating: ShanghaiTech/part_A/test_data/ground-truth/GT_IMG_5.mat
#  extracting: ShanghaiTech/part_A/test_data/ground-truth/GT_IMG_6.mat
#  extracting: ShanghaiTech/part_A/test_data/ground-truth/GT_IMG_7.mat
#   inflating: ShanghaiTech/part_A/test_data/ground-truth/GT_IMG_8.mat
#  extracting: ShanghaiTech/part_A/test_data/ground-truth/GT_IMG_9.mat
#    creating: ShanghaiTech/part_A/test_data/images/
#   inflating: ShanghaiTech/part_A/test_data/images/IMG_1.jpg
#   inflating: ShanghaiTech/part_A/test_data/images/IMG_10.jpg
#   inflating: ShanghaiTech/part_A/test_data/images/IMG_2.jpg
#   inflating: ShanghaiTech/part_A/test_data/images/IMG_3.jpg
#   inflating: ShanghaiTech/part_A/test_data/images/IMG_4.jpg
#   inflating: ShanghaiTech/part_A/test_data/images/IMG_5.jpg
#   inflating: ShanghaiTech/part_A/test_data/images/IMG_6.jpg
#   inflating: ShanghaiTech/part_A/test_data/images/IMG_7.jpg
#   inflating: ShanghaiTech/part_A/test_data/images/IMG_8.jpg
#   inflating: ShanghaiTech/part_A/test_data/images/IMG_9.jpg
#    creating: ShanghaiTech/part_A/train_data/
#    creating: ShanghaiTech/part_A/train_data/ground-truth/
#   inflating: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_1.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_10.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_11.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_12.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_13.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_14.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_15.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_16.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_17.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_18.mat
#   inflating: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_19.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_2.mat
#   inflating: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_20.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_21.mat
#   inflating: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_22.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_23.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_24.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_25.mat
#   inflating: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_26.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_27.mat
#   inflating: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_28.mat
#   inflating: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_29.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_3.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_30.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_4.mat
#   inflating: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_5.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_6.mat
#   inflating: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_7.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_8.mat
#  extracting: ShanghaiTech/part_A/train_data/ground-truth/GT_IMG_9.mat
#    creating: ShanghaiTech/part_A/train_data/images/
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_1.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_10.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_11.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_12.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_13.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_14.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_15.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_16.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_17.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_18.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_19.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_2.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_20.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_21.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_22.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_23.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_24.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_25.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_26.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_27.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_28.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_29.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_3.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_30.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_4.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_5.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_6.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_7.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_8.jpg
#   inflating: ShanghaiTech/part_A/train_data/images/IMG_9.jpg
#    creating: ShanghaiTech/part_B/
#    creating: ShanghaiTech/part_B/test_data/
#    creating: ShanghaiTech/part_B/test_data/ground-truth/
#   inflating: ShanghaiTech/part_B/test_data/ground-truth/GT_IMG_1.mat
#  extracting: ShanghaiTech/part_B/test_data/ground-truth/GT_IMG_10.mat
#  extracting: ShanghaiTech/part_B/test_data/ground-truth/GT_IMG_2.mat
#  extracting: ShanghaiTech/part_B/test_data/ground-truth/GT_IMG_3.mat
#  extracting: ShanghaiTech/part_B/test_data/ground-truth/GT_IMG_4.mat
#  extracting: ShanghaiTech/part_B/test_data/ground-truth/GT_IMG_5.mat
#  extracting: ShanghaiTech/part_B/test_data/ground-truth/GT_IMG_6.mat
#  extracting: ShanghaiTech/part_B/test_data/ground-truth/GT_IMG_7.mat
#  extracting: ShanghaiTech/part_B/test_data/ground-truth/GT_IMG_8.mat
#   inflating: ShanghaiTech/part_B/test_data/ground-truth/GT_IMG_9.mat
#    creating: ShanghaiTech/part_B/test_data/images/
#   inflating: ShanghaiTech/part_B/test_data/images/IMG_1.jpg
#   inflating: ShanghaiTech/part_B/test_data/images/IMG_10.jpg
#   inflating: ShanghaiTech/part_B/test_data/images/IMG_2.jpg
#   inflating: ShanghaiTech/part_B/test_data/images/IMG_3.jpg
#   inflating: ShanghaiTech/part_B/test_data/images/IMG_4.jpg
#   inflating: ShanghaiTech/part_B/test_data/images/IMG_5.jpg
#   inflating: ShanghaiTech/part_B/test_data/images/IMG_6.jpg
#   inflating: ShanghaiTech/part_B/test_data/images/IMG_7.jpg
#   inflating: ShanghaiTech/part_B/test_data/images/IMG_8.jpg
#   inflating: ShanghaiTech/part_B/test_data/images/IMG_9.jpg
#    creating: ShanghaiTech/part_B/train_data/
#    creating: ShanghaiTech/part_B/train_data/ground-truth/
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_1.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_10.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_11.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_12.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_13.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_14.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_15.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_16.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_17.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_18.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_19.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_2.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_20.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_21.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_22.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_23.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_24.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_25.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_26.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_27.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_28.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_29.mat
#   inflating: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_3.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_30.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_4.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_5.mat
#   inflating: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_6.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_7.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_8.mat
#  extracting: ShanghaiTech/part_B/train_data/ground-truth/GT_IMG_9.mat
#    creating: ShanghaiTech/part_B/train_data/images/
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_1.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_10.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_11.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_12.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_13.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_14.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_15.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_16.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_17.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_18.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_19.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_2.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_20.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_21.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_22.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_23.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_24.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_25.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_26.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_27.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_28.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_29.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_3.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_30.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_4.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_5.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_6.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_7.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_8.jpg
#   inflating: ShanghaiTech/part_B/train_data/images/IMG_9.jpg

# %%
# !pip install torch-summary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-summary
#   Downloading torch_summary-1.4.5-py3-none-any.whl (16 kB)
# Installing collected packages: torch-summary
# Successfully installed torch-summary-1.4.5

# %%
# !pip install pytorch-lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.0.0-py3-none-any.whl (715 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.6/715.6 KB 29.6 MB/s eta 0:00:00
# Collecting lightning-utilities>=0.7.0
#   Downloading lightning_utilities-0.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning) (4.65.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning) (4.5.0)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning) (6.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning) (1.22.4)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning) (23.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning) (2023.3.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning) (1.13.1+cu116)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 KB 52.6 MB/s eta 0:00:00
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 45.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (2.27.1)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 21.6 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 37.8 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 693.7 kB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (22.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (2.0.12)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (1.26.15)
# Installing collected packages: multidict, lightning-utilities, frozenlist, async-timeout, yarl, torchmetrics, aiosignal, aiohttp, pytorch-lightning
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 lightning-utilities-0.8.0 multidict-6.0.4 pytorch-lightning-2.0.0 torchmetrics-0.11.4 yarl-1.8.2

# %%
import pandas as pd
import numpy as np

# %%
import scipy
import scipy.io
import cv2

from matplotlib import pyplot as plt

from scipy.ndimage import gaussian_filter

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from PIL import Image

from pytorch_lightning import LightningModule, Trainer
from pytorch_lightning import seed_everything

import os

# %%
from sklearn.model_selection import train_test_split

train = [p.path for p in os.scandir('/content/ShanghaiTech/part_A/train_data/images/')]
valid_full = [p.path for p in os.scandir('/content/ShanghaiTech/part_A/test_data/images/')]

## use a small subset for validation
_, valid = train_test_split(valid_full, test_size=2, random_state=42)

len(train), len(valid)
# Out:
# (30, 2)

# %%
from torchvision import transforms
import albumentations as A
from albumentations.pytorch import ToTensorV2

# %%
im_size = 300
aug_train = A.Compose([
    A.RandomCrop(im_size, im_size),
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(),
    A.Normalize((0.5), (0.5)),
], keypoint_params=A.KeypointParams(format='xy', angle_in_degrees=False))

aug_val = A.Compose([
    A.Resize(768, 1024),
    A.Normalize((0.5), (0.5)),
], keypoint_params=A.KeypointParams(format='xy', angle_in_degrees=False))

class MyDataset(Dataset):
    def __init__(self, files, aug):
        self.files = files
        self.aug = aug
        
    def __len__(self):
        return len(self.files)
    
    def __getitem__(self, idx):
        fn = self.files[idx]
        
        im = cv2.imread(fn, cv2.IMREAD_COLOR)
        im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        
        m = scipy.io.loadmat(fn.replace('images', 'ground-truth').replace('IMG', 'GT_IMG').replace('.jpg', '.mat'))
        ps = m['image_info'][0][0][0][0][0]
        
        rst = self.aug(image=im, keypoints=ps)
        im = rst['image']
        ps = rst['keypoints']
        
        dm = np.zeros((im.shape[0], im.shape[1]), dtype=np.float32)
        for x, y in ps:
            x = int(x)
            y = int(y)
            dm[y, x] = 1

        sigma = 4
        dm = gaussian_filter(dm, sigma=sigma, truncate=4*sigma)
        
        dm = cv2.resize(dm, (im.shape[1] // 4, im.shape[0] // 4), interpolation=cv2.INTER_LINEAR)
        dm *= 16
        
        im = torch.from_numpy(im)
        dm = torch.from_numpy(dm)
        
        return im, dm

# %%
class Conv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, relu=True, same_padding=False, bn=False):
        super(Conv2d, self).__init__()
        padding = int((kernel_size - 1) / 2) if same_padding else 0
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding=padding)
        self.bn = nn.BatchNorm2d(out_channels, eps=0.001, momentum=0, affine=True) if bn else None
        self.relu = nn.ReLU(inplace=True) if relu else None

    def forward(self, x):
        x = self.conv(x)
        if self.bn is not None:
            x = self.bn(x)
        if self.relu is not None:
            x = self.relu(x)
        return x

# %%
class MCNN(LightningModule):
    '''
    Multi-column CNN 
        -Implementation of Single Image Crowd Counting via Multi-column CNN (Zhang et al.)
    '''
    
    def __init__(self, lr, batch_size, max_steps, bn=False):
        super(MCNN, self).__init__()
        
        self.lr = lr
        self.save_hyperparameters()
        
        self.use = 0
        
        self.branch1 = nn.Sequential(Conv2d( 1, 16, 9, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(16, 32, 7, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(32, 16, 7, same_padding=True, bn=bn),
                                     Conv2d(16,  8, 7, same_padding=True, bn=bn))
        
        self.branch2 = nn.Sequential(Conv2d( 1, 20, 7, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(20, 40, 5, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(40, 20, 5, same_padding=True, bn=bn),
                                     Conv2d(20, 10, 5, same_padding=True, bn=bn))
        
        self.branch3 = nn.Sequential(Conv2d( 1, 24, 5, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(24, 48, 3, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(48, 24, 3, same_padding=True, bn=bn),
                                     Conv2d(24, 12, 3, same_padding=True, bn=bn))
        
        self.fuse = nn.Sequential(Conv2d( 30, 1, 1, same_padding=True, bn=bn))
        
        self.out1 = nn.Sequential(Conv2d( 8, 1, 1, same_padding=True, bn=bn))
        self.out2 = nn.Sequential(Conv2d( 10, 1, 1, same_padding=True, bn=bn))
        self.out3 = nn.Sequential(Conv2d( 12, 1, 1, same_padding=True, bn=bn))
        
        self.crit = nn.MSELoss()
        
    def forward(self, im_data):
        im_data = im_data.unsqueeze(1)
        x1 = self.branch1(im_data)
        x2 = self.branch2(im_data)
        x3 = self.branch3(im_data)
        
        
        if self.use == 0:
            x = torch.cat((x1,x2,x3),1)
            x = self.fuse(x)
        elif self.use == 1:
            x = self.out1(x1)
        elif self.use == 2:
            x = self.out2(x2)
        elif self.use == 3:
            x = self.out3(x3)
        
        return x.squeeze(1)
    
    
    def training_step(self, batch, batch_idx):
        self.train()
        x, y = batch
        
        pred = self(x)
        loss = self.crit(pred, y)
        
        pred_sum = torch.round(pred.sum(dim=(1,2))).int()
        gt_sum = torch.round(y.sum(dim=(1,2))).int()
        acc = (pred_sum == gt_sum).float().mean()
        
        mae = torch.abs(pred_sum - gt_sum).float().mean()
        
        self.log('train_loss', loss)
        self.log('train_acc', acc)
        self.log('train_mae', mae)
        
        return loss
        
    def validation_step(self, batch, batch_idx):
        with torch.no_grad():
            self.eval()
            x, y = batch
            
            pred = self(x)
            loss = self.crit(pred, y)
        
            pred_sum = torch.round(pred.sum(dim=(1,2))).int()
            gt_sum = torch.round(y.sum(dim=(1,2))).int()
            acc = (pred_sum == gt_sum).float().mean()

            mae = torch.abs(pred_sum - gt_sum).float().mean()
            
            self.log('val_loss', loss)
            self.log('val_acc', acc)
            self.log('val_mae', mae)
            
            
    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.parameters(), lr=self.lr, weight_decay=1e-4)
        
        scheduler = {
            'scheduler': torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=self.lr, total_steps=self.hparams.max_steps, pct_start=0.1, cycle_momentum=False),
            'interval': 'step',
            'frequency': 1
        }
        
        return [optimizer], [scheduler]

# %%
def weights_normal_init(model, dev=0.01):
    if isinstance(model, list):
        for m in model:
            weights_normal_init(m, dev)
    else:
        for n, m in model.named_modules():
            if isinstance(m, nn.Conv2d):
                m.weight.data.normal_(0.0, dev)
                if m.bias is not None:
                    m.bias.data.fill_(0.0)
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0.0, dev)

# %%
batch_size = 4
epochs = 100
max_steps = epochs * len(train) // batch_size

# %%
train_loader = DataLoader(MyDataset(train, aug_train), batch_size=batch_size, shuffle=True, drop_last=True, pin_memory=True, num_workers=4)
val_loader = DataLoader(MyDataset(valid, aug_val), batch_size=batch_size, shuffle=False, drop_last=False, pin_memory=True, num_workers=4)

# %% [markdown]
# #MCNN MODEL TRAINING

# %%
from pytorch_lightning.callbacks import ModelCheckpoint, LearningRateMonitor
seed_everything(42)

checkpoint_cb = ModelCheckpoint(
    save_top_k=1,
    save_last=True,
    verbose=True,
    monitor='val_mae',
    mode='min'
)

trainer = Trainer(max_steps=max_steps, precision=16, benchmark=True, callbacks=[checkpoint_cb, LearningRateMonitor()])

lr = 3e-4

model = MCNN(lr, batch_size, max_steps)
weights_normal_init(model, dev=0.01)

model.use = 0

trainer.fit(model, train_dataloaders=train_loader, val_dataloaders=val_loader)
# Out:
# INFO:lightning_fabric.utilities.seed:Global seed set to 42
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name    | Type       | Params
# ---------------------------------------
# 0 | branch1 | Sequential | 57.8 K
# 1 | branch2 | Sequential | 46.1 K
# 2 | branch3 | Sequential | 24.0 K
# 3 | fuse    | Sequential | 31
# 4 | out1    | Sequential | 9
# 5 | out2    | Sequential | 11
# 6 | out3    | Sequential | 13
# 7 | crit    | MSELoss    | 0
# ---------------------------------------
# 127 K     Trainable params
# 0         Non-trainable params
# 127 K     Total params
# 0.512     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 0, global step 7: 'val_mae' reached 324.00000 (best 324.00000), saving model to '/content/lightning_logs/version_5/checkpoints/epoch=0-step=7.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 1, global step 14: 'val_mae' reached 315.50000 (best 315.50000), saving model to '/content/lightning_logs/version_5/checkpoints/epoch=1-step=14.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 2, global step 21: 'val_mae' reached 293.50000 (best 293.50000), saving model to '/content/lightning_logs/version_5/checkpoints/epoch=2-step=21.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 3, global step 28: 'val_mae' reached 244.00000 (best 244.00000), saving model to '/content/lightning_logs/version_5/checkpoints/epoch=3-step=28.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 4, global step 35: 'val_mae' reached 53.50000 (best 53.50000), saving model to '/content/lightning_logs/version_5/checkpoints/epoch=4-step=35.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 5, global step 42: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 6, global step 49: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 7, global step 56: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 8, global step 63: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 9, global step 70: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 10, global step 77: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 11, global step 84: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 12, global step 91: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 13, global step 98: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 14, global step 105: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 15, global step 112: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 16, global step 119: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 17, global step 126: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 18, global step 133: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 19, global step 140: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 20, global step 147: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 21, global step 154: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 22, global step 161: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 23, global step 168: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 24, global step 175: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 25, global step 182: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 26, global step 189: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 27, global step 196: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 28, global step 203: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 29, global step 210: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 30, global step 217: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 31, global step 224: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 32, global step 231: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 33, global step 238: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 34, global step 245: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 35, global step 252: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 36, global step 259: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 37, global step 266: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 38, global step 273: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 39, global step 280: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 40, global step 287: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 41, global step 294: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 42, global step 301: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 43, global step 308: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 44, global step 315: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 45, global step 322: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 46, global step 329: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 47, global step 336: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 48, global step 343: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 49, global step 350: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 50, global step 357: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 51, global step 364: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 52, global step 371: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 53, global step 378: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 54, global step 385: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 55, global step 392: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 56, global step 399: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 57, global step 406: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 58, global step 413: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 59, global step 420: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 60, global step 427: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 61, global step 434: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 62, global step 441: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 63, global step 448: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 64, global step 455: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 65, global step 462: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 66, global step 469: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 67, global step 476: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 68, global step 483: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 69, global step 490: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 70, global step 497: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 71, global step 504: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 72, global step 511: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 73, global step 518: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 74, global step 525: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 75, global step 532: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 76, global step 539: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 77, global step 546: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 78, global step 553: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 79, global step 560: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 80, global step 567: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 81, global step 574: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 82, global step 581: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 83, global step 588: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 84, global step 595: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 85, global step 602: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 86, global step 609: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 87, global step 616: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 88, global step 623: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 89, global step 630: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 90, global step 637: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 91, global step 644: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 92, global step 651: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 93, global step 658: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 94, global step 665: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 95, global step 672: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 96, global step 679: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 97, global step 686: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 98, global step 693: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 99, global step 700: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 100, global step 707: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 101, global step 714: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 102, global step 721: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 103, global step 728: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 104, global step 735: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 105, global step 742: 'val_mae' was not in top 1
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 106, global step 749: 'val_mae' was not in top 1
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 107, global step 750: 'val_mae' was not in top 1
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=750` reached.

# %% [markdown]
# # `Loading model from last checkpoint`
#
# Credits: https://www.kaggle.com/code/wptouxx/shtech-mcnn-eval/notebook

# %%
from tqdm.notebook import tqdm

# %%
model = MCNN.load_from_checkpoint('/content/lightning_logs/version_5/checkpoints/epoch=4-step=35.ckpt')
model = model.cuda()
model.eval()
rst = []
gt = []
for x, y in tqdm(val_loader):
    with torch.no_grad():
        x = x.cuda(non_blocking=True)
        pred = torch.round(model(x).sum(dim=(1,2))).int().cpu().numpy()
        
    rst.append(pred)
    gt.append(y.sum(dim=(1,2)).int().numpy())
    
rst = np.concatenate(rst, axis=0)
gt = np.concatenate(gt, axis=0)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# #MAE

# %%
print("MAE:", np.abs((rst - gt)).astype(np.float32).mean())
# Out:
# MAE: 54.0

# %% [markdown]
# #MSE

# %%
print("MSE:", ((rst - gt) ** 2).mean())
# Out:
# MSE: 3037.0

# %% [markdown]
# Convert lightning_logs to zip file so that it can be downloaded

# %%
# !zip -r /content/lightning_logs.zip /content/lightning_logs
# Out:
#   adding: content/lightning_logs/ (stored 0%)
#   adding: content/lightning_logs/version_3/ (stored 0%)
#   adding: content/lightning_logs/version_3/hparams.yaml (stored 0%)
#   adding: content/lightning_logs/version_3/events.out.tfevents.1679226034.28871191401c.829.3 (deflated 31%)
#   adding: content/lightning_logs/version_5/ (stored 0%)
#   adding: content/lightning_logs/version_5/checkpoints/ (stored 0%)
#   adding: content/lightning_logs/version_5/checkpoints/epoch=4-step=35.ckpt (deflated 8%)
#   adding: content/lightning_logs/version_5/checkpoints/last.ckpt (deflated 8%)
#   adding: content/lightning_logs/version_5/events.out.tfevents.1679226254.28871191401c.829.5 (deflated 68%)
#   adding: content/lightning_logs/version_5/hparams.yaml (stored 0%)
#   adding: content/lightning_logs/version_4/ (stored 0%)
#   adding: content/lightning_logs/version_4/checkpoints/ (stored 0%)
#   adding: content/lightning_logs/version_4/checkpoints/epoch=0-step=15.ckpt (deflated 7%)
#   adding: content/lightning_logs/version_4/checkpoints/last.ckpt (deflated 7%)
#   adding: content/lightning_logs/version_4/events.out.tfevents.1679226098.28871191401c.829.4 (deflated 58%)
#   adding: content/lightning_logs/version_4/hparams.yaml (stored 0%)
#   adding: content/lightning_logs/version_2/ (stored 0%)
#   adding: content/lightning_logs/version_2/hparams.yaml (stored 0%)
#   adding: content/lightning_logs/version_2/events.out.tfevents.1679225943.28871191401c.829.2 (deflated 31%)
#   adding: content/lightning_logs/version_1/ (stored 0%)
#   adding: content/lightning_logs/version_1/events.out.tfevents.1679225907.28871191401c.829.1 (deflated 31%)
#   adding: content/lightning_logs/version_1/hparams.yaml (stored 0%)
#   adding: content/lightning_logs/version_0/ (stored 0%)
#   adding: content/lightning_logs/version_0/hparams.yaml (stored 0%)
#   adding: content/lightning_logs/version_0/events.out.tfevents.1679225882.28871191401c.829.0 (deflated 31%)

# %% [markdown]
# Download lightning_logs.zip

# %%
from google.colab import files
files.download("/content/lightning_logs.zip")

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.4.0
# aiohttp                       3.8.4
# aiosignal                     1.3.1
# alabaster                     0.7.13
# albumentations                1.2.1
# altair                        4.2.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arviz                         0.15.1
# astropy                       5.2.1
# astunparse                    1.6.3
# async-timeout                 4.0.2
# atomicwrites                  1.4.1
# attrs                         22.2.0
# audioread                     3.0.0
# autograd                      1.5
# Babel                         2.12.1
# backcall                      0.2.0
# beautifulsoup4                4.11.2
# bleach                        6.0.0
# blis                          0.7.9
# bokeh                         2.4.3
# branca                        0.6.0
# bs4                           0.0.1
# CacheControl                  0.12.11
# cachetools                    5.3.0
# catalogue                     2.0.8
# certifi                       2022.12.7
# cffi                          1.15.1
# chardet                       3.0.4
# charset-normalizer            2.0.12
# click                         8.1.3
# cloudpickle                   2.2.1
# cmake                         3.25.2
# cmdstanpy                     1.1.0
# colorcet                      3.0.1
# colorlover                    0.3.0
# community                     1.0.0b1
# confection                    0.0.4
# cons                          0.4.5
# contextlib2                   0.6.0.post1
# contourpy                     1.0.7
# convertdate                   2.4.0
# cufflinks                     0.17.3
# cupy-cuda11x                  11.0.0
# cvxopt                        1.3.0
# cvxpy                         1.3.0
# cycler                        0.11.0
# cymem                         2.0.7
# Cython                        0.29.33
# dask                          2022.12.1
# datascience                   0.17.6
# db-dtypes                     1.0.5
# dbus-python                   1.2.16
# debugpy                       1.6.6
# decorator                     4.4.2
# defusedxml                    0.7.1
# distributed                   2022.12.1
# dlib                          19.24.0
# dm-tree                       0.1.8
# docutils                      0.16
# dopamine-rl                   1.0.5
# earthengine-api               0.1.345
# easydict                      1.10
# ecos                          2.0.12
# editdistance                  0.5.3
# en-core-web-sm                3.5.0
# entrypoints                   0.4
# ephem                         4.1.4
# et-xmlfile                    1.1.0
# etils                         1.1.0
# etuples                       0.3.8
# fastai                        2.7.11
# fastcore                      1.5.28
# fastdownload                  0.0.7
# fastjsonschema                2.16.3
# fastprogress                  1.0.3
# fastrlock                     0.8.1
# filelock                      3.10.0
# firebase-admin                5.3.0
# fix-yahoo-finance             0.0.22
# Flask                         2.2.3
# flatbuffers                   23.3.3
# folium                        0.12.1.post1
# fonttools                     4.39.0
# frozenlist                    1.3.3
# fsspec                        2023.3.0
# future                        0.18.3
# gast                          0.4.0
# GDAL                          3.3.2
# gdown                         4.6.4
# gensim                        3.6.0
# geographiclib                 1.52
# geopy                         1.17.0
# gin-config                    0.5.0
# glob2                         0.7
# google                        2.0.3
# google-api-core               2.11.0
# google-api-python-client      2.70.0
# google-auth                   2.16.2
# google-auth-httplib2          0.1.0
# google-auth-oauthlib          0.4.6
# google-cloud-bigquery         3.4.2
# google-cloud-bigquery-storage 2.19.0
# google-cloud-core             2.3.2
# google-cloud-datastore        2.11.1
# google-cloud-firestore        2.7.3
# google-cloud-language         2.6.1
# google-cloud-storage          2.7.0
# google-cloud-translate        3.8.4
# google-colab                  1.0.0
# google-crc32c                 1.5.0
# google-pasta                  0.2.0
# google-resumable-media        2.4.1
# googleapis-common-protos      1.58.0
# googledrivedownloader         0.4
# graphviz                      0.10.1
# greenlet                      2.0.2
# grpcio                        1.51.3
# grpcio-status                 1.48.2
# gspread                       3.4.2
# gspread-dataframe             3.0.8
# gym                           0.25.2
# gym-notices                   0.0.8
# h5netcdf                      1.1.0
# h5py                          3.8.0
# HeapDict                      1.0.1
# hijri-converter               2.2.4
# holidays                      0.21.13
# holoviews                     1.14.9
# html5lib                      1.1
# htmlmin                       0.1.12
# httpimport                    1.3.0
# httplib2                      0.21.0
# humanize                      4.6.0
# hyperopt                      0.2.7
# idna                          3.4
# ImageHash                     4.3.1
# imageio                       2.9.0
# imagesize                     1.4.1
# imbalanced-learn              0.10.1
# imblearn                      0.0
# imgaug                        0.4.0
# importlib-metadata            6.0.0
# importlib-resources           5.12.0
# imutils                       0.5.4
# inflect                       6.0.2
# intel-openmp                  2023.0.0
# ipykernel                     5.3.4
# ipython                       7.9.0
# ipython-genutils              0.2.0
# ipython-sql                   0.3.9
# ipywidgets                    7.7.1
# itsdangerous                  2.1.2
# jax                           0.4.6
# jaxlib                        0.4.6+cuda11.cudnn86
# jieba                         0.42.1
# Jinja2                        3.1.2
# joblib                        1.1.1
# jsonschema                    4.3.3
# jupyter-client                6.1.12
# jupyter-console               6.1.0
# jupyter_core                  5.2.0
# jupyterlab-pygments           0.2.2
# jupyterlab-widgets            3.0.5
# kaggle                        1.5.13
# keras                         2.11.0
# keras-vis                     0.4.1
# kiwisolver                    1.4.4
# korean-lunar-calendar         0.3.1
# langcodes                     3.3.0
# lazy_loader                   0.1
# libclang                      15.0.6.1
# librosa                       0.10.0
# lightgbm                      3.3.5
# lightning-utilities           0.8.0
# llvmlite                      0.39.1
# locket                        1.0.0
# logical-unification           0.4.5
# LunarCalendar                 0.0.9
# lxml                          4.9.2
# Markdown                      3.4.1
# MarkupSafe                    2.1.2
# matplotlib                    3.7.1
# matplotlib-venn               0.11.9
# miniKanren                    1.0.3
# missingno                     0.5.2
# mistune                       0.8.4
# mizani                        0.8.1
# mkl                           2019.0
# mlxtend                       0.14.0
# more-itertools                9.1.0
# moviepy                       0.2.3.5
# mpmath                        1.3.0
# msgpack                       1.0.5
# multidict                     6.0.4
# multimethod                   1.9.1
# multipledispatch              0.6.0
# multitasking                  0.0.11
# murmurhash                    1.0.9
# music21                       5.5.0
# natsort                       5.5.0
# nbclient                      0.7.2
# nbconvert                     6.5.4
# nbformat                      5.7.3
# networkx                      3.0
# nibabel                       3.0.2
# nltk                          3.8.1
# notebook                      6.3.0
# numba                         0.56.4
# numexpr                       2.8.4
# numpy                         1.22.4
# oauth2client                  4.1.3
# oauthlib                      3.2.2
# opencv-contrib-python         4.6.0.66
# opencv-python                 4.6.0.66
# opencv-python-headless        4.7.0.72
# opendatasets                  0.1.22
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# osqp                          0.6.2.post0
# packaging                     23.0
# palettable                    3.3.0
# pandas                        1.4.4
# pandas-datareader             0.10.0
# pandas-gbq                    0.17.9
# pandas-profiling              3.2.0
# pandocfilters                 1.5.0
# panel                         0.14.4
# param                         1.13.0
# parso                         0.8.3
# partd                         1.3.0
# pathlib                       1.0.1
# pathy                         0.10.1
# patsy                         0.5.3
# pep517                        0.13.0
# pexpect                       4.8.0
# phik                          0.12.3
# pickleshare                   0.7.5
# Pillow                        8.4.0
# pip                           22.0.4
# pip-tools                     6.6.2
# platformdirs                  3.1.1
# plotly                        5.5.0
# plotnine                      0.10.1
# pluggy                        0.7.1
# pooch                         1.7.0
# portpicker                    1.3.9
# prefetch-generator            1.0.3
# preshed                       3.0.8
# prettytable                   3.6.0
# progressbar2                  3.38.0
# prometheus-client             0.16.0
# promise                       2.3
# prompt-toolkit                2.0.10
# prophet                       1.1.2
# proto-plus                    1.22.2
# protobuf                      3.19.6
# psutil                        5.9.4
# psycopg2                      2.9.5
# ptyprocess                    0.7.0
# py                            1.11.0
# py4j                          0.10.9.7
# pyarrow                       9.0.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.6
# pycparser                     2.21
# pyct                          0.5.0
# pydantic                      1.10.6
# pydata-google-auth            1.7.0
# pydot                         1.3.0
# pydot-ng                      2.0.0
# pydotplus                     2.0.2
# PyDrive                       1.3.1
# pyerfa                        2.0.0.1
# Pygments                      2.6.1
# PyGObject                     3.36.0
# pymc                          5.1.2
# PyMeeus                       0.5.12
# pymystem3                     0.2.0
# PyOpenGL                      3.1.6
# pyparsing                     3.0.9
# pyrsistent                    0.19.3
# PySocks                       1.7.1
# pytensor                      2.10.1
# pytest                        3.6.4
# python-apt                    0.0.0
# python-dateutil               2.8.2
# python-louvain                0.16
# python-slugify                8.0.1
# python-utils                  3.5.2
# pytorch-lightning             2.0.0
# pytz                          2022.7.1
# pytz-deprecation-shim         0.1.0.post0
# pyviz-comms                   2.2.1
# PyWavelets                    1.4.1
# PyYAML                        6.0
# pyzmq                         23.2.1
# qdldl                         0.1.5.post3
# qudida                        0.0.4
# regex                         2022.10.31
# requests                      2.27.1
# requests-oauthlib             1.3.1
# requests-unixsocket           0.2.0
# rpy2                          3.5.5
# rsa                           4.9
# scikit-image                  0.19.3
# scikit-learn                  1.2.2
# scipy                         1.10.1
# screen-resolution-extra       0.0.0
# scs                           3.2.2
# seaborn                       0.12.2
# Send2Trash                    1.8.0
# setuptools                    63.4.3
# shapely                       2.0.1
# six                           1.15.0
# sklearn-pandas                2.2.0
# smart-open                    6.3.0
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# soundfile                     0.12.1
# soupsieve                     2.4
# soxr                          0.3.4
# spacy                         3.5.1
# spacy-legacy                  3.0.12
# spacy-loggers                 1.0.4
# Sphinx                        3.5.4
# sphinxcontrib-applehelp       1.0.4
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.1
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# SQLAlchemy                    1.4.46
# sqlparse                      0.4.3
# srsly                         2.4.6
# statsmodels                   0.13.5
# sympy                         1.11.1
# tables                        3.7.0
# tabulate                      0.8.10
# tangled-up-in-unicode         0.2.0
# tblib                         1.7.0
# tenacity                      8.2.2
# tensorboard                   2.11.2
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.11.0
# tensorflow-datasets           4.8.3
# tensorflow-estimator          2.11.0
# tensorflow-gcs-config         2.11.0
# tensorflow-hub                0.13.0
# tensorflow-io-gcs-filesystem  0.31.0
# tensorflow-metadata           1.12.0
# tensorflow-probability        0.19.0
# termcolor                     2.2.0
# terminado                     0.17.1
# text-unidecode                1.3
# textblob                      0.17.1
# thinc                         8.1.9
# threadpoolctl                 3.1.0
# tifffile                      2023.3.15
# tinycss2                      1.2.1
# toml                          0.10.2
# tomli                         2.0.1
# toolz                         0.12.0
# torch                         1.13.1+cu116
# torch-summary                 1.4.5
# torchaudio                    0.13.1+cu116
# torchmetrics                  0.11.4
# torchsummary                  1.5.1
# torchtext                     0.14.1
# torchvision                   0.14.1+cu116
# tornado                       6.2
# tqdm                          4.65.0
# traitlets                     5.7.1
# tweepy                        4.13.0
# typer                         0.7.0
# typing_extensions             4.5.0
# tzdata                        2022.7
# tzlocal                       4.2
# uritemplate                   4.1.1
# urllib3                       1.26.15
# vega-datasets                 0.9.0
# visions                       0.7.4
# wasabi                        1.1.1
# wcwidth                       0.2.6
# webencodings                  0.5.1
# Werkzeug                      2.2.3
# wheel                         0.40.0
# widgetsnbextension            3.6.2
# wordcloud                     1.8.2.2
# wrapt                         1.15.0
# xarray                        2022.12.0
# xarray-einstats               0.5.1
# xgboost                       1.7.4
# xkit                          0.0.0
# xlrd                          2.0.1
# xlwt                          1.3.0
# yarl                          1.8.2
# yellowbrick                   1.5
# zict                          2.2.0
# zipp                          3.15.0
